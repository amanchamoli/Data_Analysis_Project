# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("food_Analysis\Data\indian_food_cleaned.csv")

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavour dish_type        state region
# 0  vegetarian         45         25   sweet   dessert  west bengal   east
# 1  vegetarian         80         30   sweet   dessert    rajasthan   west
# 2  vegetarian         15         60   sweet   dessert       punjab  north
# 3  vegetarian         15         30   sweet   dessert    rajasthan   west
# 4  vegetarian         15         40   sweet   dessert  west bengal   east

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         383 non-null    object
#  1   ingredients  383 non-null    object
#  2   diet         383 non-null    object
#  3   prep_time    383 non-null    int64
#  4   cook_time    383 non-null    int64
#  5   flavour      383 non-null    object
#  6   dish_type    383 non-null    object
#  7   state        383 non-null    object
#  8   region       383 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 27.1+ KB

# %%
df[df["name"].duplicated()]
# Out:
#                  name                                        ingredients  \
# 276       crab masala  crab, onion, tomato, ginger, garlic, chili pow...
# 285   chicken biryani         chicken, rice, onion, tomato, curd, masala
# 286    mutton biryani          mutton, rice, onion, tomato, curd, spices
# 293        fish curry  fish, coconut, turmeric, chili, mustard, curry...
# 298      prawn masala  prawn, onion, tomato, chili, curry leaves, masala
# 302     prawn biryani           prawn, rice, onion, tomato, mint, masala
# 305      mutton curry      mutton, onion, tomato, garlic, ginger, masala
# 306         egg curry                  egg, onion, tomato, chili, spices
# 307          fish fry     fish, chili powder, turmeric, lemon juice, oil
# 309   chicken biryani         chicken, rice, onion, tomato, curd, masala
# 312       prawn roast    prawn, chili, pepper, curry leaves, coconut oil
# 313  meen pollichathu   fish, chili, onion, tomato, coconut, banana leaf
# 315   chicken biryani         chicken, rice, onion, tomato, masala, ghee
# 320        fish curry      fish, coconut, tamarind, chili, mustard seeds
# 321    mutton biryani          mutton, rice, onion, tomato, curd, masala
# 322   chicken biryani         chicken, rice, onion, tomato, curd, masala
# 323         egg curry                  egg, onion, tomato, chili, masala
# 324         prawn fry    prawn, chili powder, turmeric, lemon juice, oil
# 327     chicken sukka      chicken, coconut, chili, pepper, curry leaves
# 335      mutton curry      mutton, onion, tomato, garlic, ginger, masala
# 336         egg curry                 egg, tomato, onion, garlic, masala
# 337   chicken biryani         chicken, rice, onion, tomato, curd, masala
# 338    mutton biryani          mutton, rice, onion, tomato, curd, masala
# 339       prawn curry                prawn, onion, tomato, chili, garlic
# 344        fish curry           fish, onion, tomato, chili, mustard, oil
# 345       mutton stew       mutton, onion, tomato, garlic, pepper, clove
# 350     chicken handi              chicken, onion, tomato, cream, spices
# 352      mutton curry       mutton, onion, tomato, chili, garlic, ginger
# 353       prawn curry       prawn, mustard, chili, garlic, tomato, onion
# 354       crab masala        crab, onion, tomato, chili, coconut, masala
# 355          fish fry     fish, chili powder, turmeric, lemon juice, oil
# 356    mutton biryani          mutton, rice, onion, tomato, curd, masala
# 357   chicken biryani         chicken, rice, onion, tomato, curd, masala
# 358         egg curry             egg, onion, tomato, chili, garlic, oil
# 368      mutton curry      mutton, onion, tomato, garlic, ginger, masala
# 369         egg curry             egg, onion, tomato, chili, garlic, oil
# 370        fish curry      fish, coconut, tamarind, chili, mustard seeds
# 371     chicken roast             chicken, chili, ginger, garlic, masala
# 379          fish fry  bhetki fish, chili, bread crumbs, lemon juice,...
# 380    mutton biryani          mutton, rice, potato, onion, ghee, spices
#
#                diet  prep_time  cook_time flavour    dish_type          state  \
# 276  non vegetarian         40         90   spicy  main course     tamil nadu
# 285  non vegetarian         40         85   spicy  main course     tamil nadu
# 286  non vegetarian         45         95   spicy  main course     tamil nadu
# 293  non vegetarian         35         70   spicy  main course     tamil nadu
# 298  non vegetarian         35         80   spicy  main course     tamil nadu
# 302  non vegetarian         40         85   spicy  main course      karnataka
# 305  non vegetarian         45         95   spicy  main course      karnataka
# 306  non vegetarian         30         70   spicy  main course      karnataka
# 307  non vegetarian         30         65   spicy      starter      karnataka
# 309  non vegetarian         40         90   spicy  main course      karnataka
# 312  non vegetarian         35         80   spicy  main course         kerala
# 313  non vegetarian         30         75   spicy  main course         kerala
# 315  non vegetarian         40         90   spicy  main course         kerala
# 320  non vegetarian         35         80   spicy  main course    maharashtra
# 321  non vegetarian         40         95   spicy  main course    maharashtra
# 322  non vegetarian         40         90   spicy  main course    maharashtra
# 323  non vegetarian         30         70   spicy  main course    maharashtra
# 324  non vegetarian         30         65   spicy      starter    maharashtra
# 327  non vegetarian         35         80   spicy      starter    maharashtra
# 335  non vegetarian         45        100   spicy  main course         punjab
# 336  non vegetarian         30         70   spicy  main course         punjab
# 337  non vegetarian         40         90   spicy  main course         punjab
# 338  non vegetarian         45         95   spicy  main course         punjab
# 339  non vegetarian         35         80   spicy  main course         punjab
# 344  non vegetarian         35         80   spicy  main course         punjab
# 345  non vegetarian         45         95   spicy  main course         punjab
# 350  non vegetarian         40         90   spicy  main course         punjab
# 352  non vegetarian         40         90   spicy  main course         odisha
# 353  non vegetarian         35         80   spicy  main course         odisha
# 354  non vegetarian         40         90   spicy  main course         odisha
# 355  non vegetarian         30         70   spicy      starter         odisha
# 356  non vegetarian         45         95   spicy  main course         odisha
# 357  non vegetarian         40         90   spicy  main course         odisha
# 358  non vegetarian         30         70   spicy  main course         odisha
# 368  non vegetarian         45         95   spicy  main course  uttar pradesh
# 369  non vegetarian         30         70   spicy  main course  uttar pradesh
# 370  non vegetarian         35         80   spicy  main course  uttar pradesh
# 371  non vegetarian         40         85   spicy      starter  uttar pradesh
# 379  non vegetarian         30         65   spicy      starter    west bengal
# 380  non vegetarian         45         95   spicy  main course    west bengal
#
#     region
# 276  south
# 285  south
# 286  south
# 293  south
# 298  south
# 302  south
# 305  south
# 306  south
# 307  south
# 309  south
# 312  south
# 313  south
# 315  south
# 320   west
# 321   west
# 322   west
# 323   west
# 324   west
# 327   west
# 335  north
# 336  north
# 337  north
# 338  north
# 339  north
# 344  north
# 345  north
# 350  north
# 352   east
# 353   east
# 354   east
# 355   east
# 356   east
# 357   east
# 358   east
# 368  north
# 369  north
# 370  north
# 371  north
# 379   east
# 380   east

# %%
df['diet'] = df['diet'].astype('category')
df['flavour'] = df['flavour'].astype('category')

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         0 non-null      object
#  1   ingredients  383 non-null    object
#  2   diet         383 non-null    category
#  3   prep_time    383 non-null    int64
#  4   cook_time    383 non-null    int64
#  5   total_time   383 non-null    int64
#  6   flavour      383 non-null    category
#  7   dish_type    383 non-null    object
#  8   state        383 non-null    object
#  9   region       383 non-null    object
# dtypes: category(2), int64(3), object(5)
# memory usage: 25.1+ KB
#         prep_time   cook_time  total_time
# count  383.000000  383.000000  383.000000
# mean    34.404700   51.112272   85.516971
# std     53.680465   27.098046   65.731598
# min      5.000000    2.000000   10.000000
# 25%     10.000000   30.000000   45.000000
# 50%     27.000000   40.000000   65.000000
# 75%     35.000000   77.500000  115.000000
# max    500.000000  120.000000  620.000000

# %% [markdown]
# UNIVARIATE ANALYSIS

# %% [markdown]
# 1. Name

# %%
df['name'].nunique()
# Out:
# 343

# %% [markdown]
# 2. Ingredients
# - avg 7-8 ingredients per dish

# %%
df['ingredients'].str.split().str.len().describe()

#average 7 ingredients per dish
# Out:
# count    383.000000
# mean       6.864230
# std        2.157988
# min        2.000000
# 25%        6.000000
# 50%        7.000000
# 75%        8.000000
# max       13.000000
# Name: ingredients, dtype: float64

# %%
df['ingredients'].str.len().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 3. diet
# - veg dominating list

# %%
df['diet'].value_counts()
# Out:
# diet
# vegetarian        226
# non vegetarian    157
# Name: count, dtype: int64

# %%
#percentage 
round(df['diet'].value_counts(normalize=True)*100, 2)
# Out:
# diet
# vegetarian        59.01
# non vegetarian    40.99
# Name: proportion, dtype: float64

# %%
#Plot
df['diet'].value_counts().plot(kind='bar', color=['green', 'orange'])
# Out:
# <Axes: xlabel='diet'>

# %% [markdown]
# 4. prep time
# - avg time for prep is 30-35 min
# - valid outliers

# %%
df['prep_time'].describe()
# Out:
# count    383.000000
# mean      34.404700
# std       53.680465
# min        5.000000
# 25%       10.000000
# 50%       27.000000
# 75%       35.000000
# max      500.000000
# Name: prep_time, dtype: float64

# %%
sns.boxplot(x=df['prep_time'])
#valid outliers
# Out:
# <Axes: xlabel='prep_time'>

# %% [markdown]
# 5. cook time
# - avg time for cook is 30-35 min
# - valid outliers

# %%
df['cook_time'].describe()
# Out:
# count    383.000000
# mean      51.112272
# std       27.098046
# min        2.000000
# 25%       30.000000
# 50%       40.000000
# 75%       77.500000
# max      120.000000
# Name: cook_time, dtype: float64

# %%
sns.boxplot(x=df['cook_time'])
#valid outliers
# Out:
# <Axes: xlabel='cook_time'>

# %% [markdown]
# 6. flavour
# - 50% dishes are spicy

# %%
df['flavour'].value_counts()
df['flavour'].value_counts().plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='flavour'>

# %%
df['flavour'].value_counts().plot(kind= 'pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 7. dish_type
# - 50% are main dish

# %%
df['dish_type'].value_counts()
df['dish_type'].value_counts().plot(kind='bar', color='purple')
# Out:
# <Axes: xlabel='dish_type'>

# %%
df['dish_type'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# dishes per category

df['dish_type'].value_counts().plot(kind='bar',color=['lightgreen', 'skyblue', 'pink'],
    figsize=(7,4)
)
plt.xlabel("dish type")
plt.ylabel("no of Dishes")
plt.show()

# %% [markdown]
# 8. state
# - gujarat, punjab, maharashtra are the dominating ones

# %%
df['state'].nunique()    # 25
df['state'].value_counts().head(10)
# Out:
# state
# tamil nadu       58
# punjab           53
# gujarat          52
# maharashtra      48
# west bengal      34
# uttar pradesh    22
# assam            21
# odisha           17
# kerala           17
# karnataka        17
# Name: count, dtype: int64

# %%
df['state'].value_counts().head(10).plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# 9. region
# - unexpectedly northeast region have the less number of dishes
# - other half of india dominating the list ( west, south)

# %%
df['region'].nunique()   # 6
# Out:
# 6

# %%
round(df['region'].value_counts(normalize=True)*100, 2)
# Out:
# region
# west          29.24
# south         28.20
# north         21.93
# east          13.32
# north east     6.53
# central        0.78
# Name: proportion, dtype: float64

# %%
df['region'].value_counts().plot(kind='bar', color='lightgreen')
# Out:
# <Axes: xlabel='region'>

# %%
df['region'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
#total_time column
df['total_time'] = df['prep_time'] + df['cook_time']
df.insert(5, 'total_time', df.pop('total_time'))

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time  total_time flavour dish_type  \
# 0  vegetarian         45         25          70   sweet   dessert
# 1  vegetarian         80         30         110   sweet   dessert
# 2  vegetarian         15         60          75   sweet   dessert
# 3  vegetarian         15         30          45   sweet   dessert
# 4  vegetarian         15         40          55   sweet   dessert
#
#          state region
# 0  west bengal   east
# 1    rajasthan   west
# 2       punjab  north
# 3    rajasthan   west
# 4  west bengal   east

# %%
#diet vs total_time
# diet vs region
# diet vs state
# diet vs flavour

# %%
# diet vs total_time
df.groupby('diet')['total_time'].mean().plot(kind='bar')

# not so different
# Out:
# C:\Temp\ipykernel_7872\3492322976.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('diet')['total_time'].mean().plot(kind='bar')
# <Axes: xlabel='diet'>

# %%
# diet vs region
df.groupby('region')['diet'].value_counts().unstack().plot(kind='bar', figsize=(8,5))
plt.ylabel("no of dishes")
plt.show()

# valid differences coz rajasthan, gujarat are veg dominant regions

# %%
# diet vs state
df.groupby('state')['diet'].value_counts().unstack().plot(kind='bar', figsize=(8,5))
plt.ylabel("no of dishes")
plt.show()

# %%
['gujarat','maharashtra','punjab','tamil nadu','west bengal','odisha','andhra pradesh']
# Out:
# ['gujarat',
#  'maharashtra',
#  'punjab',
#  'tamil nadu',
#  'west bengal',
#  'odisha',
#  'andhra pradesh']

# %% [markdown]
# in graph tamilnadu is purely vegetarian state but in reality it is not
# same goes for maharashtra, andhra, west bengal, punjab and UP
#
# - two possible reason
# 1. cleaning or assessing problem
# 2. or may be dataset created in this way

# %%
# diet vs flavour
df.groupby('diet')['flavour'].value_counts().unstack().plot(kind='bar', figsize=(8,5))
plt.ylabel('no of dishes')
plt.show()

# non veg dishes are not sweet dishes at all
# Out:
# C:\Temp\ipykernel_7872\1114772368.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('diet')['flavour'].value_counts().unstack().plot(kind='bar', figsize=(8,5))

# %%
#total_time vs flavour
#total_time vs dish_type
#total_time vs region

# %%
#total_time vs flavour
df.groupby('flavour')['total_time'].mean().plot(kind='bar')


# both sweet and spicy are almost take same time
# Out:
# C:\Temp\ipykernel_7872\2426524515.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('flavour')['total_time'].mean().plot(kind='bar')
# <Axes: xlabel='flavour'>

# %%
#total_time vs dish_type
df.groupby('dish_type')['total_time'].mean().plot(kind='bar')

# generally starter take more time
# Out:
# <Axes: xlabel='dish_type'>

# %%
#total_time vs region
df.groupby('region')['total_time'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='region'>

# %%
# flavour vs dish_type 
#2. flavour vs region 
#4. flavour vs diet

# %%
## flavour vs dish_type 
df.groupby('flavour')['dish_type'].value_counts().unstack().plot(kind='bar')

# starter - spicy
# main - spicy
# dessert - sweet
# Out:
# C:\Temp\ipykernel_7872\1091668916.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('flavour')['dish_type'].value_counts().unstack().plot(kind='bar')
# <Axes: xlabel='flavour'>

# %%
# flavour vs region
df.groupby('flavour')['region'].value_counts().unstack().plot(kind='bar')

# spicy dominant in west,north, south regions
# Out:
# C:\Temp\ipykernel_7872\2140408214.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('flavour')['region'].value_counts().unstack().plot(kind='bar')
# <Axes: xlabel='flavour'>

# %%
#dish_type vs region
df.groupby('dish_type')['region'].value_counts().unstack().plot(kind='bar')

# northest doesn't like starter at all
# same for north
# south likes main course
# Out:
# <Axes: xlabel='dish_type'>

# %%
# multivariate analysis (region, dish_type vs total_time)
pd.crosstab(df['region'], df['dish_type'],values=df['total_time'],aggfunc='mean').round(1).plot(kind='bar', figsize=(10,6))

plt.show()

# south starter dishes take more time
